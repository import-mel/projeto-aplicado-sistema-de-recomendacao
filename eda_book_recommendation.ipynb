# %% [markdown]
# ## Análise Exploratória de Dados
#
# > **Link para o repositório no Kaggle:** [Book Recommendation Dataset](https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset/data)

# %% [markdown]
# ### Import das Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Carregamento dos Dados

# %%
df_books_v1 = pd.read_csv('./data/Books.csv')
df_ratings_v1 = pd.read_csv('./data/Ratings.csv')
df_users_v1 = pd.read_csv('./data/Users.csv')
# Out:
# /var/folders/jv/x960ph5j46g4834_92nzcq900000gp/T/ipykernel_30564/4095636204.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_books_v1 = pd.read_csv('./data/Books.csv')

# %% [markdown]
# ###  Entendimento dos Dados

# %% [markdown]
# ##### **`df_books`**

# %%
df_books_v1.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
print(f"A tabela df_books possui {df_books_v1.shape[0]} linhas e {df_books_v1.shape[1]} colunas.")
# Out:
# A tabela df_books possui 271360 linhas e 8 colunas.

# %%
df_books_v1.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
# 5               Amy Tan                1991            Putnam Pub Group
# 6         Robert Cowley                2000    Berkley Publishing Group
# 7           Scott Turow                1993                  Audioworks
# 8       David Cordingly                1996                Random House
# 9           Ann Beattie                2002                    Scribner
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
# 5  http://images.amazon.com/images/P/0399135782.0...
# 6  http://images.amazon.com/images/P/0425176428.0...
# 7  http://images.amazon.com/images/P/0671870432.0...
# 8  http://images.amazon.com/images/P/0679425608.0...
# 9  http://images.amazon.com/images/P/074322678X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
# 5  http://images.amazon.com/images/P/0399135782.0...
# 6  http://images.amazon.com/images/P/0425176428.0...
# 7  http://images.amazon.com/images/P/0671870432.0...
# 8  http://images.amazon.com/images/P/0679425608.0...
# 9  http://images.amazon.com/images/P/074322678X.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
# 5  http://images.amazon.com/images/P/0399135782.0...
# 6  http://images.amazon.com/images/P/0425176428.0...
# 7  http://images.amazon.com/images/P/0671870432.0...
# 8  http://images.amazon.com/images/P/0679425608.0...
# 9  http://images.amazon.com/images/P/074322678X.0...

# %%
df_books_v1.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# freq                                                    2
#
#                                               Image-URL-L
# count                                              271357
# unique                                             271041
# top     http://images.amazon.com/images/P/225307649X.0...
# freq                                                    2

# %%
print("Tipos dos dados: ")
df_books_v1.info()
# Out:
# Tipos dos dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
print("Quantidade de valores nulos em cada coluna: ")
df_books_v1.isnull().sum()
# Out:
# Valores nulos em cada coluna:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
print('Quantidade de valores duplicados: ')
df_books_v1.apply(lambda col: col.duplicated().sum())
# Out:
# Quantidade de valores duplicados:
# ISBN                        0
# Book-Title              29225
# Book-Author            169337
# Year-Of-Publication    271158
# Publisher              254552
# Image-URL-S               316
# Image-URL-M               316
# Image-URL-L               318
# dtype: int64

# %% [markdown]
# #### **`df_users`**

# %%
df_users_v1.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %%
print(f"A tabela df_users possui {df_users_v1.shape[0]} linhas e {df_users_v1.shape[1]} colunas.")
# Out:
# A tabela df_users possui 278858 linhas e 3 colunas.

# %%
df_users_v1.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
df_users_v1.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %% [markdown]
# **Observação:** Como "User-ID" é um identificador único, não têm muito significado prático em termos de análise de usuários.

# %%
print("Tipos dos dados:")
df_users_v1.info()
# Out:
# Tipos dos dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
print("Quantidade de valores nulos em cada coluna: ")
df_users_v1.isnull().sum()
# Out:
# Quantidade de valores nulos em cada coluna:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %% [markdown]
# #### **`df_ratings`**

# %%
df_ratings_v1.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
print(f"A tabela df_ratings possui {df_ratings_v1.shape[0]} linhas e {df_ratings_v1.shape[1]} colunas.")
# Out:
# A tabela df_ratings possui 1149780 linhas e 3 colunas.

# %%
df_ratings_v1.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
df_ratings_v1.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
print("Tipos dos dados:")
df_ratings_v1.info()
# Out:
# Tipos dos dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
print("Quantidade de valores nulos em cada coluna: ")
df_ratings_v1.isnull().sum()
# Out:
# Quantidade de valores nulos em cada coluna:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %% [markdown]
# ## Perguntas que iremos direcionar a análise:

# %% [markdown]
# ##### **Tabela `books`**
#
# - Quais são os autores mais publicados na base de dados?
# - Quais são as editoras que publicaram mais livros?
# - Como os livros estão distribuídos ao longo dos anos de publicação?
# - Há livros com títulos duplicados, mas com ISBNs diferentes? Se sim, o que isso pode significar?
# - Existem livros sem autor ou sem editora informada?
# - Há alguma correlação entre autores específicos e editoras?
# - Quantos livros únicos existem na base de dados?

# %%
print('-----------------------------------------------------------------------------')
print('Quais são os autores mais publicados na base de dados?')
print('-----------------------------------------------------------------------------')

autores_contagem = df_books_v1['Book-Author'].value_counts()
top_autores = autores_contagem.head(10)
print(top_autores)

cores = sns.color_palette("rocket", n_colors=10)

plt.figure(figsize=(10, 6))
top_autores.plot(kind='bar', color=cores)
plt.title('Top 10 Autores Mais Publicados')
plt.xlabel('Autor')
plt.ylabel('Quantidade de Livros')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()
plt.show()
# Out:
# -----------------------------------------------------------------------------
# Quais são os autores mais publicados na base de dados?
# -----------------------------------------------------------------------------
# Book-Author
# Agatha Christie        632
# William Shakespeare    567
# Stephen King           524
# Ann M. Martin          423
# Carolyn Keene          373
# Francine Pascal        372
# Isaac Asimov           330
# Nora Roberts           315
# Barbara Cartland       307
# Charles Dickens        302
# Name: count, dtype: int64

# %%
print('-----------------------------------------------------------------------------')
print('Quais são as editoras que publicaram mais livros?')
print('-----------------------------------------------------------------------------')

editoras_contagem = df_books_v1['Publisher'].value_counts()
top_editoras = editoras_contagem.head(10)
print(top_editoras)

cores = sns.color_palette("rocket", n_colors=10)

plt.figure(figsize=(10, 6))
top_editoras.plot(kind='bar', color=cores)
plt.title('Top 10 Autores Mais Publicados')
plt.xlabel('Autor')
plt.ylabel('Quantidade de Livros')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

print(f"\nEditoras que menos publicaram na tabela:  \n{editoras_contagem.tail(10)}")
# Out:
# -----------------------------------------------------------------------------
# Quais são as editoras que publicaram mais livros?
# -----------------------------------------------------------------------------
# Publisher
# Harlequin                   7535
# Silhouette                  4220
# Pocket                      3905
# Ballantine Books            3783
# Bantam Books                3646
# Scholastic                  3160
# Simon &amp; Schuster        2971
# Penguin Books               2844
# Berkley Publishing Group    2771
# Warner Books                2727
# Name: count, dtype: int64
# Editoras que menos publicaram na tabela:
# Publisher
# Sands Pub Llc                    1
# Shadow Line Press                1
# ImaJinn Books                    1
# Windstream Publishing Company    1
# Polaris Books                    1
# Hannover House                   1
# Amber Quill Press, LLC.          1
# Lunchbox Press                   1
# Ugly Town                        1
# Connaught                        1
# Name: count, dtype: int64

# %%
print('-----------------------------------------------------------------------------')
print('Como os livros estão distribuídos ao longo dos anos de publicação?')
print('-----------------------------------------------------------------------------')

df_books_v1['Year-Of-Publication'] = pd.to_numeric(df_books_v1['Year-Of-Publication'], errors='coerce')

livros_por_ano = df_books_v1['Year-Of-Publication'].value_counts().sort_index()

print(livros_por_ano.head(100))

plt.figure(figsize=(18, 10))
livros_por_ano.plot(kind='line', color='blue', marker='o')
plt.title('Distribuição de Livros ao Longo dos Anos de Publicação')
plt.xlabel('Ano de Publicação')
plt.ylabel('Quantidade de Livros')
plt.grid(True)
plt.tight_layout()
plt.show()

top_livros_por_ano = df_books_v1['Year-Of-Publication'].value_counts().sort_values(ascending=False)

print("Anos que mais registraram livros:")
print(top_livros_por_ano.head(15)) 

plt.figure(figsize=(18, 10))
top_livros_por_ano.head(15).plot(kind='bar', color=cores)
plt.title('Distribuição de Livros ao Longo dos Anos de Publicação')
plt.xlabel('Ano de Publicação')
plt.ylabel('Quantidade de Livros')
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# -----------------------------------------------------------------------------
# Como os livros estão distribuídos ao longo dos anos de publicação?
# -----------------------------------------------------------------------------
# Year-Of-Publication
# 0.0        4618
# 1376.0        1
# 1378.0        1
# 1806.0        1
# 1897.0        1
#           ...
# 1998.0    15766
# 1999.0    17431
# 2000.0    17232
# 2001.0    17359
# 2002.0    17627
# Name: count, Length: 100, dtype: int64
# Anos que mais registraram livros:
# Year-Of-Publication
# 2002.0    17627
# 1999.0    17431
# 2001.0    17359
# 2000.0    17232
# 1998.0    15766
# 1997.0    14890
# 2003.0    14358
# 1996.0    14030
# 1995.0    13546
# 1994.0    11796
# 1993.0    10602
# 1992.0     9906
# 1991.0     9389
# 1990.0     8660
# 1989.0     7936
# Name: count, dtype: int64

# %%
print('-----------------------------------------------------------------------------')
print('Há livros com títulos duplicados, mas com ISBNs diferentes? Se sim, o que isso pode significar?')
print('-----------------------------------------------------------------------------')

duplicados = df_books_v1[df_books_v1.duplicated(subset=['Book-Title'], keep=False)]

# Filtrar apenas os casos em que o título é duplicado, mas os ISBNs são diferentes
duplicados_isbn_diferentes = duplicados.groupby('Book-Title').filter(lambda x: len(x['ISBN'].unique()) > 1)
print(duplicados_isbn_diferentes[['Book-Title', 'ISBN']].shape[0])
duplicados_isbn_diferentes
# Out:
# -----------------------------------------------------------------------------
# Há livros com títulos duplicados, mas com ISBNs diferentes? Se sim, o que isso pode significar?
# -----------------------------------------------------------------------------
# 49132
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 5       0399135782                             The Kitchen God's Wife
# 6       0425176428  What If?: The World's Foremost Military Histor...
# 9       074322678X            Where You'll Find Me: And Other Stories
# 13      1552041778                                           Jane Doe
# ...            ...                                                ...
# 271246  0195124995  For Cause and Comrades: Why Men Fought in the ...
# 271315  1902852036                                All the Queen's Men
# 271316  0441011799                                    Singularity Sky
# 271346  0395264707                                         Dreamsnake
# 271355  0440400988                         There's a Bat in Bunk Five
#
#                Book-Author  Year-Of-Publication  \
# 0       Mark P. O. Morford               2002.0
# 5                  Amy Tan               1991.0
# 6            Robert Cowley               2000.0
# 9              Ann Beattie               2002.0
# 13            R. J. Kaiser               1999.0
# ...                    ...                  ...
# 271246  James M. McPherson               1998.0
# 271315         Nick Elwood               1999.0
# 271316      Charles Stross               2004.0
# 271346   Vonda N. McIntyre               1978.0
# 271355      Paula Danziger               1988.0
#
#                               Publisher  \
# 0               Oxford University Press
# 5                      Putnam Pub Group
# 6              Berkley Publishing Group
# 9                              Scribner
# 13                           Mira Books
# ...                                 ...
# 271246          Oxford University Press
# 271315                  Gay Men's Press
# 271316                              Ace
# 271346                 Houghton Mifflin
# 271355  Random House Childrens Pub (Mm)
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 5       http://images.amazon.com/images/P/0399135782.0...
# 6       http://images.amazon.com/images/P/0425176428.0...
# 9       http://images.amazon.com/images/P/074322678X.0...
# 13      http://images.amazon.com/images/P/1552041778.0...
# ...                                                   ...
# 271246  http://images.amazon.com/images/P/0195124995.0...
# 271315  http://images.amazon.com/images/P/1902852036.0...
# 271316  http://images.amazon.com/images/P/0441011799.0...
# 271346  http://images.amazon.com/images/P/0395264707.0...
# 271355  http://images.amazon.com/images/P/0440400988.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 5       http://images.amazon.com/images/P/0399135782.0...
# 6       http://images.amazon.com/images/P/0425176428.0...
# 9       http://images.amazon.com/images/P/074322678X.0...
# 13      http://images.amazon.com/images/P/1552041778.0...
# ...                                                   ...
# 271246  http://images.amazon.com/images/P/0195124995.0...
# 271315  http://images.amazon.com/images/P/1902852036.0...
# 271316  http://images.amazon.com/images/P/0441011799.0...
# 271346  http://images.amazon.com/images/P/0395264707.0...
# 271355  http://images.amazon.com/images/P/0440400988.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 5       http://images.amazon.com/images/P/0399135782.0...
# 6       http://images.amazon.com/images/P/0425176428.0...
# 9       http://images.amazon.com/images/P/074322678X.0...
# 13      http://images.amazon.com/images/P/1552041778.0...
# ...                                                   ...
# 271246  http://images.amazon.com/images/P/0195124995.0...
# 271315  http://images.amazon.com/images/P/1902852036.0...
# 271316  http://images.amazon.com/images/P/0441011799.0...
# 271346  http://images.amazon.com/images/P/0395264707.0...
# 271355  http://images.amazon.com/images/P/0440400988.0...
#
# [49132 rows x 8 columns]

# %%
print('-----------------------------------------------------------------------------')
print('Quantos livros únicos existem na base de dados?')
print('-----------------------------------------------------------------------------')

livros_unicos = df_books_v1['Book-Title'].nunique()
print(f"Quantidade de livros únicos na base de dados: {livros_unicos}")
# Out:
# -----------------------------------------------------------------------------
# Quantos livros únicos existem na base de dados?
# -----------------------------------------------------------------------------
# Quantidade de livros únicos na base de dados: 242135

# %% [markdown]
# ##### **Tabela `users`**
#
# - De quais localizações (cidades, estados, países) os usuários são majoritariamente originários? Há concentrações específicas de usuários em determinadas regiões?
# - Qual é a distribuição etária dos usuários? Há faixas etárias predominantes entre os usuários?
# - Há usuários com idades inconsistentes ou fora de uma faixa razoável (por exemplo, menores de 5 anos ou maiores de 100)?
# - Existem faixas etárias predominantes em determinadas localizações?
# - A idade média varia de acordo com a localização dos usuários?
# - Há faixas etárias predominantes entre os usuários?
# - Qual é a média, mediana e desvio padrão das idades?
# - Qual é a idade mínima e máxima registrada?

# %%
print('-----------------------------------------------------------------------------')
print('De quais localizações (cidades, estados, países) os usuários são majoritariamente originários? Há concentrações específicas de usuários em determinadas regiões?')
print('-----------------------------------------------------------------------------')

usuarios_por_localizacao = df_users_v1['Location'].value_counts()
print(usuarios_por_localizacao.head(10)) 

plt.figure(figsize=(12, 6))
usuarios_por_localizacao.head(10).plot(kind='bar', color=cores)
plt.title('Top 10 Localizações de Usuários')
plt.xlabel('Localização')
plt.ylabel('Quantidade de Usuários')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print(f"Localizações com menos usuários: {usuarios_por_localizacao.tail(10)}")
# Out:
# -----------------------------------------------------------------------------
# De quais localizações (cidades, estados, países) os usuários são majoritariamente originários? Há concentrações específicas de usuários em determinadas regiões?
# -----------------------------------------------------------------------------
# Location
# london, england, united kingdom        2506
# toronto, ontario, canada               2250
# sydney, new south wales, australia     1744
# melbourne, victoria, australia         1708
# portland, oregon, usa                  1629
# chicago, illinois, usa                 1526
# seattle, washington, usa               1484
# new york, new york, usa                1411
# madrid, madrid, spain                  1400
# vancouver, british columbia, canada    1359
# Name: count, dtype: int64
# Localizações com menos usuários: Location
# estella, n/a, spain                              1
# smethport, pennsylvania, usa                     1
# kehrsatz, alaska, switzerland                    1
# uedem, nordrheinwestfalen, germany               1
# bredbury, stockport, united kingdom              1
# gneisenaustr. 3, nordrhein-westfalen, germany    1
# -, bayern, germany                               1
# bouchegouf, guelma, algeria                      1
# indiana and philadelphia, pennsylvania, usa      1
# tacoma, washington, united kingdom               1
# Name: count, dtype: int64

# %%
print('-----------------------------------------------------------------------------')
print('Qual é a distribuição etária dos usuários? Há faixas etárias predominantes entre os usuários?')
print('Há usuários com idades inconsistentes ou fora de uma faixa razoável (por exemplo, menores de 5 anos ou maiores de 100)?')
print('-----------------------------------------------------------------------------')

plt.figure(figsize=(10, 6))
plt.hist(df_users_v1['Age'].dropna(), bins=20, color=sns.color_palette("rocket", n_colors=1)[0], edgecolor='black')
plt.title('Distribuição Etária dos Usuários')
plt.xlabel('Idade')
plt.ylabel('Quantidade de Usuários')
plt.grid(True)
plt.tight_layout()
plt.show()

faixas_etarias = [0, 18, 25, 35, 45, 55, 65, 100, 200, 300]

df_users_v1['Faixa Etária'] = pd.cut(df_users_v1['Age'], bins=faixas_etarias, right=False)

# Contar a quantidade de usuários em cada faixa etária
distribuicao_faixas = df_users_v1['Faixa Etária'].value_counts().sort_index()

# Exibir a distribuição das faixas etárias
print(distribuicao_faixas)
# Out:
# -----------------------------------------------------------------------------
# Qual é a distribuição etária dos usuários? Há faixas etárias predominantes entre os usuários?
# Há usuários com idades inconsistentes ou fora de uma faixa razoável (por exemplo, menores de 5 anos ou maiores de 100)?
# -----------------------------------------------------------------------------
# Faixa Etária
# [0, 18)       12310
# [18, 25)      32004
# [25, 35)      50767
# [35, 45)      32690
# [45, 55)      23152
# [55, 65)      12493
# [65, 100)      4307
# [100, 200)      345
# [200, 300)       28
# Name: count, dtype: int64

# %%
print('-----------------------------------------------------------------------------')
print('Existem faixas etárias predominantes em determinadas localizações?')
print('-----------------------------------------------------------------------------')

faixas_etarias = [18, 25, 35, 45, 55, 65, 100]
labels = ['18-25', '26-35', '36-45', '46-55', '56-65', '66-100']

df_users_v1['Faixa Etária'] = pd.cut(df_users_v1['Age'], bins=faixas_etarias, labels=labels, right=False)

# Contar o número de usuários por localização e selecionar as 15 mais frequentes
top_15_localizacoes = df_users_v1['Location'].value_counts().head(15).index

# Filtrar apenas as localizações mais frequentes
df_top_locations = df_users_v1[df_users_v1['Location'].isin(top_15_localizacoes)]

# Agrupar por localização e faixa etária
distribuicao_etaria_localizacao = df_top_locations.groupby(['Location', 'Faixa Etária']).size().unstack().fillna(0)

# Plotar o gráfico de barras empilhadas
plt.figure(figsize=(12, 6))
distribuicao_etaria_localizacao.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='Set3')
plt.title('Distribuição das Faixas Etárias por Localização (Top 15)')
plt.xlabel('Localização')
plt.ylabel('Número de Usuários')
plt.xticks(rotation=90)
plt.legend(title='Faixa Etária', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

print(distribuicao_etaria_localizacao)
# Out:
# -----------------------------------------------------------------------------
# Existem faixas etárias predominantes em determinadas localizações?
# -----------------------------------------------------------------------------
# /var/folders/jv/x960ph5j46g4834_92nzcq900000gp/T/ipykernel_51330/2586856012.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   distribuicao_etaria_localizacao = df_top_locations.groupby(['Location', 'Faixa Etária']).size().unstack().fillna(0)
# Faixa Etária                         18-25  26-35  36-45  46-55  56-65  66-100
# Location
# berlin, berlin, germany                152    342    185     59     21       4
# chicago, illinois, usa                 130    344    168    127     76      20
# houston, texas, usa                     62    156    131     96     69      26
# london, england, united kingdom        268    807    315    110     52      13
# madrid, madrid, spain                  335    626    192     93     21       7
# melbourne, victoria, australia         212    303    184    138     55      19
# new york, new york, usa                126    278    124     90     42      22
# ottawa, ontario, canada                124    224    133     81     60      10
# portland, oregon, usa                   81    188    137     88     79      21
# san diego, california, usa              58    152    110    149     51      21
# san francisco, california, usa          88    214    135     77     44       9
# seattle, washington, usa                82    251    170    108     80      13
# sydney, new south wales, australia     245    389    193    100     63      15
# toronto, ontario, canada               227    447    238    144     78      17
# vancouver, british columbia, canada     72    187    116     68     38      14

# %%
print('-----------------------------------------------------------------------------')
print('A idade média varia de acordo com a localização dos usuários?')
print('-----------------------------------------------------------------------------')

idade_media_por_localizacao = df_users_v1.groupby('Location')['Age'].mean()

idade_media_top15 = df_top_locations.groupby('Location')['Age'].mean().sort_values(ascending=False)

top_5_maiores = idade_media_por_localizacao.nlargest(5)
top_5_menores = idade_media_por_localizacao.nsmallest(5)


plt.figure(figsize=(12, 6))
idade_media_top15.plot(kind='bar', color=cores)

for i, valor in enumerate(idade_media_top15):
    plt.text(i, valor + 0.5, f"{valor:.1f}", ha='center', fontsize=10)

plt.title('Idade Média dos Usuários nas Top 15 Localizações')
plt.xlabel('Localização')
plt.ylabel('Idade Média')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

print(f"Média de idade nas top 15 localizações: {idade_media_top15}")
print(f"\nTop 5 maiores médias: {top_5_maiores}")
print(f"\nTop 5 menores médias: \n{top_5_menores}")
# Out:
# -----------------------------------------------------------------------------
# A idade média varia de acordo com a localização dos usuários?
# -----------------------------------------------------------------------------
# Média de idade nas top 15 localizações: Location
# san diego, california, usa             39.698440
# houston, texas, usa                    38.272572
# portland, oregon, usa                  37.568720
# seattle, washington, usa               36.855615
# san francisco, california, usa         35.841026
# chicago, illinois, usa                 35.726257
# vancouver, british columbia, canada    35.530841
# new york, new york, usa                35.146099
# ottawa, ontario, canada                34.400875
# toronto, ontario, canada               33.571661
# melbourne, victoria, australia         32.474227
# berlin, berlin, germany                32.305170
# london, england, united kingdom        32.041743
# madrid, madrid, spain                  30.163527
# sydney, new south wales, australia     28.357396
# Name: Age, dtype: float64
#
# Top 5 maiores médias: Location
# akure, ondo/nigeria, nigeria             231.0
# olympia, cascadia, usa                   226.0
# santa maria da feira, porto, portugal    223.0
# christchurch, canterbury, nz             220.0
# arrasate, gipuzkoa, euskal herria        209.0
# Name: Age, dtype: float64
#
# Top 5 menores médias:
# Location
# aberfeldy, scotland, united kingdom              0.0
# abingdon, oxon, united kingdom                   0.0
# accra, maine, ghana                              0.0
# adfdaf, australian capital territory, albania    0.0
# alal, alabama, albania                           0.0
# Name: Age, dtype: float64

# %%
print('-----------------------------------------------------------------------------')
print('Há faixas etárias predominantes entre os usuários?')
print('-----------------------------------------------------------------------------')


bins = [0, 18, 25, 35, 45, 55, 65, 75, 85, 95, 110]
labels = ['0-18', '19-25', '26-35', '36-45', '46-55', '56-65', '66-75', '76-85', '86-95', '96-110']

# Criar uma nova coluna com as faixas etárias
df_users_v1['Faixa_Etaria'] = pd.cut(df_users_v1['Age'], bins=bins, labels=labels, right=True)

# Contar o número de usuários em cada faixa etária
distribuicao_faixas = df_users_v1['Faixa_Etaria'].value_counts().sort_index()

# Exibir a contagem em formato de dicionário
resultado = distribuicao_faixas.to_dict()
print(resultado)

plt.figure(figsize=(10, 5))
sns.barplot(x=distribuicao_faixas.index, y=distribuicao_faixas.values, palette=cores)
plt.title("Distribuição de Usuários por Faixa Etária", fontsize=14)
plt.xlabel("Faixa Etária", fontsize=12)
plt.ylabel("Número de Usuários", fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
for i, valor in enumerate(distribuicao_faixas):
    plt.text(i, valor + 10, str(valor), ha='center', fontsize=10)

plt.show()
# Out:
# -----------------------------------------------------------------------------
# Há faixas etárias predominantes entre os usuários?
# -----------------------------------------------------------------------------
# {'0-18': 15597, '19-25': 33919, '26-35': 49343, '36-45': 31014, '46-55': 22519, '56-65': 11201, '66-75': 3122, '76-85': 513, '86-95': 67, '96-110': 289}
# /var/folders/jv/x960ph5j46g4834_92nzcq900000gp/T/ipykernel_51330/1955886216.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=distribuicao_faixas.index, y=distribuicao_faixas.values, palette=cores)

# %%
print('-----------------------------------------------------------------------------')
print('Qual é a média, mediana e desvio padrão das idades?')
print('-----------------------------------------------------------------------------')

# Filtrar idades inválidas (NaN, 0 e >110)
df_users = df_users_v1[(df_users_v1['Age'].notna())]

# Calcular estatísticas
media_idade = df_users['Age'].mean()
mediana_idade = df_users['Age'].median()
desvio_padrao_idade = df_users['Age'].std()

# Exibir resultados
print(f"Média das idades: {media_idade:.2f}")
print(f"Mediana das idades: {mediana_idade}")
print(f"Desvio padrão das idades: {desvio_padrao_idade:.2f}")
# Out:
# -----------------------------------------------------------------------------
# Qual é a média, mediana e desvio padrão das idades?
# -----------------------------------------------------------------------------
# Média das idades: 34.75
# Mediana das idades: 32.0
# Desvio padrão das idades: 14.43

# %%
print('-----------------------------------------------------------------------------')
print('Qual é a idade mínima e máxima registrada?')
print('-----------------------------------------------------------------------------')

idade_minima = df_users['Age'].min()
idade_maxima = df_users['Age'].max()

print(f"Idade mínima registrada: {idade_minima}")
print(f"Idade máxima registrada: {idade_maxima}")
# Out:
# -----------------------------------------------------------------------------
# Qual é a idade mínima e máxima registrada?
# -----------------------------------------------------------------------------
# Idade mínima registrada: 0.0
# Idade máxima registrada: 244.0

# %% [markdown]
# ##### **Tabela `ratings`**
#
# - Como as avaliações dos livros estão distribuídas (por exemplo, quantas são 1 estrela, 5 estrelas, etc.)?
# - Há tendências de avaliações mais altas ou mais baixas para determinados livros, autores ou editoras?
# - Quantos usuários avaliaram livros?
# - Quantos livros foram avaliados?
# - Autores específicas tendem a receber avaliações mais altas ou mais baixas?
# - Há diferenças nas avaliações dadas por usuários de diferentes faixas etárias ou localizações?
# - Quais são os livros mais populares com base no número de avaliações?
# - Usuários de quais localizações ou faixas etárias tendem a avaliar mais livros?

# %%
print('-----------------------------------------------------------------------------')
print('Como as avaliações dos livros estão distribuídas (por exemplo, quantas são 1 estrela, 5 estrelas, etc.)?')
print('-----------------------------------------------------------------------------')

distribuicao_avaliacoes = df_ratings_v1['Book-Rating'].value_counts().sort_index()

print(distribuicao_avaliacoes)

plt.figure(figsize=(10, 6))
sns.barplot(x=distribuicao_avaliacoes.index, y=distribuicao_avaliacoes.values, palette="rocket")
plt.xlabel("Nota da Avaliação")
plt.ylabel("Quantidade de Avaliações")
plt.title("Distribuição das Avaliações dos Livros")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.xticks(rotation=0)
plt.show()
# Out:
# -----------------------------------------------------------------------------
# Como as avaliações dos livros estão distribuídas (por exemplo, quantas são 1 estrela, 5 estrelas, etc.)?
# -----------------------------------------------------------------------------
# Book-Rating
# 0     716109
# 1       1770
# 2       2759
# 3       5996
# 4       8904
# 5      50974
# 6      36924
# 7      76457
# 8     103736
# 9      67541
# 10     78610
# Name: count, dtype: int64
# /var/folders/jv/x960ph5j46g4834_92nzcq900000gp/T/ipykernel_30564/300856816.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=distribuicao_avaliacoes.index, y=distribuicao_avaliacoes.values, palette="rocket")

# %%
print('-----------------------------------------------------------------------------')
print('Há tendências de avaliações mais altas ou mais baixas para determinados livros, autores ou editoras?')
print('-----------------------------------------------------------------------------')

# Mesclar avaliações com os títulos dos livros
df_livros_avaliacoes = df_ratings_v1.merge(df_books_v1[['ISBN', 'Book-Title']], on='ISBN', how='left')

# Calcular a média das avaliações e a quantidade de avaliações por livro
estatisticas_livros = df_livros_avaliacoes.groupby(['ISBN', 'Book-Title'])['Book-Rating'].agg(['mean', 'count'])

# Renomear colunas para melhor compreensão
estatisticas_livros.columns = ['Média de Avaliação', 'Quantidade de Avaliações']

# Ordenar pelos livros mais bem avaliados (com pelo menos 5 avaliações para evitar outliers)
estatisticas_livros = estatisticas_livros[estatisticas_livros['Quantidade de Avaliações'] >= 5]
estatisticas_livros = estatisticas_livros.sort_values(by='Média de Avaliação', ascending=False)

# Exibir os 10 livros mais bem avaliados
print("Top 10 livros mais bem avaliados:")
print(estatisticas_livros.head(10))

# Exibir os 10 livros com as piores avaliações
print("\n10 livros com as piores avaliações:")
print(estatisticas_livros.tail(10))

df_livros_editoras = df_books_v1[['ISBN', 'Publisher']]  # Tabela ISBN x Editoras
df_ratings_editoras = df_ratings_v1.merge(df_livros_editoras, on='ISBN')  # Juntar tabelas
# Out:
# -----------------------------------------------------------------------------
# Há tendências de avaliações mais altas ou mais baixas para determinados livros, autores ou editoras?
# -----------------------------------------------------------------------------
# 📖 Top 10 livros mais bem avaliados:
#                                                                Média de Avaliação  \
# ISBN       Book-Title
# 0395193958 The Lord of the Rings (Leatherette Collector's ...           10.000000
# 096265342X Principia Discordia                                           9.800000
# 1561840564 Prometheus Rising                                             9.666667
# 014050639X Each Peach Pear Plum (Picture Puffins)                        9.600000
# 0060609176 Meeting Jesus Again for the First Time : The Hi...            9.600000
# 0823401898 The Shrinking of Treehorn                                     9.500000
# 0385326335 A Letter to Mrs. Roosevelt                                    9.500000
# 1563891336 Death: The High Cost of Living                                9.444444
# 1563893339 Death : The Time of Your Life (Death)                         9.428571
# 0399147888 Under Fire                                                    9.400000
#
#                                                                Quantidade de Avaliações
# ISBN       Book-Title
# 0395193958 The Lord of the Rings (Leatherette Collector's ...                         6
# 096265342X Principia Discordia                                                        5
# 1561840564 Prometheus Rising                                                          6
# 014050639X Each Peach Pear Plum (Picture Puffins)                                     5
# 0060609176 Meeting Jesus Again for the First Time : The Hi...                         5
# 0823401898 The Shrinking of Treehorn                                                  8
# 0385326335 A Letter to Mrs. Roosevelt                                                 8
# 1563891336 Death: The High Cost of Living                                             9
# 1563893339 Death : The Time of Your Life (Death)                                      7
# 0399147888 Under Fire                                                                 5
#
# 📖 10 livros com as piores avaliações:
#                                                                Média de Avaliação  \
# ISBN       Book-Title
# 0307127745 The Merry Christmas Mystery (Golden Look-Look B...                 0.0
# 0307126927 Disney's Aladdin (Golden Look-Look Book)                           0.0
# 0373261853 Appearance Of Evil                                                 0.0
# 0590420046 Kristy and the Walking Disaster (Baby-Sitters C...                 0.0
# 0590420054 Mallory and the Trouble With Twins (Baby-Sitter...                 0.0
# 0373262051 Deadly Schedule                                                    0.0
# 0373262108 Blood Sympathy                                                     0.0
# 1578150477 Longshot                                                           0.0
# 0590420062 Jessi Ramsey, Pet Sitter (Baby-Sitters Club (Pa...                 0.0
# 037311611X Such Dark Magic (Year Down Under) (Harlequin Pr...                 0.0
#
#                                                                Quantidade de Avaliações
# ISBN       Book-Title
# 0307127745 The Merry Christmas Mystery (Golden Look-Look B...                         5
# 0307126927 Disney's Aladdin (Golden Look-Look Book)                                   7
# 0373261853 Appearance Of Evil                                                         8
# 0590420046 Kristy and the Walking Disaster (Baby-Sitters C...                         8
# 0590420054 Mallory and the Trouble With Twins (Baby-Sitter...                         9
# 0373262051 Deadly Schedule                                                            8
# 0373262108 Blood Sympathy                                                             7
# 1578150477 Longshot                                                                   6
# 0590420062 Jessi Ramsey, Pet Sitter (Baby-Sitters Club (Pa...                         9
# 037311611X Such Dark Magic (Year Down Under) (Harlequin Pr...                         7

# %%
media_editoras = df_ratings_editoras.groupby('Publisher')['Book-Rating'].mean().sort_values(ascending=False)
print(f"Editoras com melhores avaliações: {media_editoras.head(10)}")
print(f"\nEditoras com piores avaliações: {media_editoras.tail(10)}")
# Out:
# Editoras com melhores avaliações: Publisher
#  Editions P. Terrail                         10.0
# Interstellar Publishing Company              10.0
# Institute for Food and Development Policy    10.0
# Instructor Books                             10.0
# T.A. Williams                                10.0
# AuthorsOmniscient Publishers                 10.0
# World Class Pubns                            10.0
# Szwede Slavic Books                          10.0
# Interscience                                 10.0
# Interstate Publishers                        10.0
# Name: Book-Rating, dtype: float64
#
# Editoras com piores avaliações: Publisher
# Lawrence Erlbaum Associates             0.0
# Law School Admission Council.           0.0
# Laurier Books Ltd.                      0.0
# Laurel Pr                               0.0
# Laureate Press                          0.0
# Laura Geringer Book                     0.0
# Laughing Tree Press                     0.0
# Latin American Literary Review Press    0.0
# Late Night Press                        0.0
# Ã?Â¶bv&amp;hpt                          0.0
# Name: Book-Rating, dtype: float64

# %%
print('-----------------------------------------------------------------------------')
print('Quantos usuários avaliaram livros?')
print('-----------------------------------------------------------------------------')

usuarios_unicos = df_ratings_v1['User-ID'].nunique()
print(f"Total de usuários que avaliaram livros: {usuarios_unicos}")
# Out:
# -----------------------------------------------------------------------------
# Quantos usuários avaliaram livros?
# -----------------------------------------------------------------------------
# Total de usuários que avaliaram livros: 105283

# %%
print('-----------------------------------------------------------------------------')
print('Quantos livros foram avaliados?')
print('-----------------------------------------------------------------------------')

livros_avaliados = df_ratings_v1['ISBN'].nunique()
print(f"Total de livros avaliados: {livros_avaliados}")

isbn_nao_encontrados = df_ratings_v1[~df_ratings_v1['ISBN'].isin(df_books_v1['ISBN'])]['ISBN'].unique()
print(f"Número de ISBNs que estão na tabela de avaliações, mas não na tabela de livros: {len(isbn_nao_encontrados)}")
# Out:
# -----------------------------------------------------------------------------
# Quantos livros foram avaliados?
# -----------------------------------------------------------------------------
# Total de livros avaliados: 340556
# Número de ISBNs que estão na tabela de avaliações, mas não na tabela de livros: 70405

# %%
print('-----------------------------------------------------------------------------')
print('Autores específicos tendem a receber avaliações mais altas ou mais baixas?')
print('-----------------------------------------------------------------------------')

df_autores_avaliacoes = df_ratings_v1.merge(df_books_v1[['ISBN', 'Book-Author']], on='ISBN', how='left')

media_avaliacoes_autores = df_autores_avaliacoes.groupby('Book-Author')['Book-Rating'].agg(['mean', 'count'])

media_avaliacoes_autores = media_avaliacoes_autores.sort_values(by='mean', ascending=False)

print("Top 10 autores com maior média de avaliações:")
print(media_avaliacoes_autores.head(10))

print("\nTop 10 autores com menor média de avaliações:")
print(media_avaliacoes_autores.tail(10))
# Out:
# -----------------------------------------------------------------------------
# Autores ou editoras específicas tendem a receber avaliações mais altas ou mais baixas?
# -----------------------------------------------------------------------------
# Top 10 autores com maior média de avaliações:
#                                 mean  count
# Book-Author
# Paula Richardson Fleming        10.0      1
# Elizabeth Zimmermann            10.0      1
# Joseph Sheppard                 10.0      1
# Jimmy A.                        10.0      1
# Arlen Schumer                   10.0      1
# Minerva T. Bloom                10.0      1
# Julie V Watson                  10.0      1
# Arkadii Natanovich Strugatskii  10.0      1
# Stephen Pollington              10.0      2
# Mink Mole                       10.0      1
#
# Top 10 autores com menor média de avaliações:
#                       mean  count
# Book-Author
# John Carvel            0.0      1
# John Carver            0.0      1
# John Cavanagh          0.0      5
# John Chancellor        0.0      3
# John Chandler          0.0      1
# John Charles Pollock   0.0      1
# John Charmley          0.0      1
# John Clanchy           0.0      2
# John Clark Craig       0.0      1
# Ã?Â?ric Holder         0.0      4

# %%
media_avaliacoes_autores_filtro = media_avaliacoes_autores[media_avaliacoes_autores['count'] > 5]

media_avaliacoes_autores_filtro = media_avaliacoes_autores_filtro.sort_values(by='mean', ascending=False)

print("Top 10 autores com mais de 5 avaliações e maior média de avaliações:")
print(media_avaliacoes_autores_filtro.head(10))

print("\nTop 10 autores com mais de 5 avaliações e menor média de avaliações:\n")
print(media_avaliacoes_autores_filtro.tail(10))
# Out:
# Top 10 autores com mais de 5 avaliações e maior média de avaliações:
#                                       mean  count
# Book-Author
# Michiro Ueyama                   10.000000     13
# Federal Aviation Administration  10.000000      6
# David R. Hawkins                 10.000000      7
# Laura Numeroff Joffe             10.000000      6
# Dick Dudley                      10.000000      6
# Pete Abrams                       9.888889      9
# Steve Goodier                     9.833333      6
# Simon Furman                      9.777778      9
# Mitsumasa Anno                    9.636364     11
# C. COCO DE YOUNG                  9.500000      8
#
# Top 10 autores com mais de 5 avaliações e menor média de avaliações:
#
#                     mean  count
# Book-Author
# Dev Stryker          0.0      7
# Diana Kramer-Rolls   0.0      6
# Denise Lynn          0.0      6
# Denee Cody           0.0      7
# Diann Thornley       0.0      6
# Diane Stortz         0.0      9
# Dieter Wellershoff   0.0      9
# Dick Stivers         0.0     60
# Diana Blayne         0.0      9
# John Clarkson        0.0     13

# %%
print('-----------------------------------------------------------------------------')
print('Há diferenças nas avaliações dadas por usuários de diferentes faixas etárias ou localizações?')
print('-----------------------------------------------------------------------------')

df_avaliacoes_faixa_etaria = df_ratings_v1.merge(df_users_v1[['User-ID', 'Age']], on='User-ID', how='left')

faixas_etarias = [0, 18, 30, 40, 50, 60, 70, 80, 100]
labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-100']

df_avaliacoes_faixa_etaria['Faixa-Etaria'] = pd.cut(df_avaliacoes_faixa_etaria['Age'], bins=faixas_etarias, labels=labels, right=False)

media_avaliacoes_faixa_etaria = df_avaliacoes_faixa_etaria.groupby('Faixa-Etaria')['Book-Rating'].mean()

print("Média das avaliações por faixa etária:")
print(media_avaliacoes_faixa_etaria)
# Out:
# -----------------------------------------------------------------------------
# Há diferenças nas avaliações dadas por usuários de diferentes faixas etárias ou localizações?
# -----------------------------------------------------------------------------
# Média das avaliações por faixa etária:
# Faixa-Etaria
# 0-18      3.649432
# 19-30     2.953481
# 31-40     2.628444
# 41-50     2.758253
# 51-60     2.876778
# 61-70     2.351151
# 71-80     4.489386
# 81-100    3.136147
# Name: Book-Rating, dtype: float64
# /var/folders/jv/x960ph5j46g4834_92nzcq900000gp/T/ipykernel_30564/1042394957.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   media_avaliacoes_faixa_etaria = df_avaliacoes_faixa_etaria.groupby('Faixa-Etaria')['Book-Rating'].mean()

# %%
df_avaliacoes_localizacao = df_ratings_v1.merge(df_users_v1[['User-ID', 'Location']], on='User-ID', how='left')

avaliacoes_por_localizacao = df_avaliacoes_localizacao.groupby('Location')['Book-Rating'].count()

localizacoes_com_mais_5_avaliacoes = avaliacoes_por_localizacao[avaliacoes_por_localizacao > 5].index

df_avaliacoes_localizacao_filtrada = df_avaliacoes_localizacao[df_avaliacoes_localizacao['Location'].isin(localizacoes_com_mais_5_avaliacoes)]

media_avaliacoes_localizacao = df_avaliacoes_localizacao_filtrada.groupby('Location')['Book-Rating'].mean()

print("Média das avaliações por localização (Top 10 com mais de 5 avaliações):")
print(media_avaliacoes_localizacao.sort_values(ascending=False).head(10))

print("\nMédia das avaliações por localização (Bottom 10 com mais de 5 avaliações):")
print(media_avaliacoes_localizacao.sort_values(ascending=True).head(10))
# Out:
# Média das avaliações por localização (Top 10 com mais de 5 avaliações):
# Location
# schinznach-dorf, aargau, switzerland     10.000000
# tröbnitz, thueringen, germany            10.000000
# paia, hawaii, usa                        10.000000
# divide, colorado, usa                    10.000000
# centerville, georgia, usa                 9.894737
# mountain city, tennessee, usa             9.833333
# bayamon, puerto rico, usa                 9.833333
# lahore, punjab,                           9.625000
# méxico, d.f., disrito federal, mexico     9.588235
# barstow, illinois, usa                    9.500000
# Name: Book-Rating, dtype: float64
#
# Média das avaliações por localização (Bottom 10 com mais de 5 avaliações):
# Location
# mirecourt, lorraine, france          0.0
# nienburg, niedersachsen, germany     0.0
# newport, ohio, usa                   0.0
# new iberia, louisiana, usa           0.0
# new cumberland, pennsylvania,        0.0
# naucalpan, edo. de méxico, mexico    0.0
# n/a, rheinland-pfalz, germany        0.0
# n/a, n/a, spain                      0.0
# n/a, n/a, solomon islands            0.0
# n/a, n/a, france                     0.0
# Name: Book-Rating, dtype: float64

# %%
print('-----------------------------------------------------------------------------')
print('Quais são os livros mais populares com base no número de avaliações?')
print('-----------------------------------------------------------------------------')

avaliacoes_por_livro = df_ratings_v1.groupby('ISBN')['Book-Rating'].count()

livros_mais_populares = avaliacoes_por_livro.sort_values(ascending=False)

top_30_livros_populares = livros_mais_populares.head(30)

livros_com_nomes = df_books_v1[df_books_v1['ISBN'].isin(top_30_livros_populares.index)]

resultados_populares = top_30_livros_populares.loc[livros_com_nomes['ISBN']].to_frame().join(livros_com_nomes.set_index('ISBN')['Book-Title'])

print("Livros mais populares com base no número de avaliações:")
print(resultados_populares)
# Out:
# -----------------------------------------------------------------------------
# Quais são os livros mais populares com base no número de avaliações?
# -----------------------------------------------------------------------------
# Livros mais populares com base no número de avaliações:
#             Book-Rating                                         Book-Title
# ISBN
# 0971880107         2502                                        Wild Animus
# 0804106304          519                                  The Joy Luck Club
# 0671027360          586                                Angels &amp; Demons
# 0452282152          526                          Girl with a Pearl Earring
# 044023722X          647                                    A Painted House
# 0142001740          615                            The Secret Life of Bees
# 0316666343         1295                          The Lovely Bones: A Novel
# 044021145X          529                                           The Firm
# 0671021001          468              She's Come Undone (Oprah's Book Club)
# 0312195516          723                The Red Tent (Bestselling Backlist)
# 0312278586          474                         The Nanny Diaries: A Novel
# 0156027321          462                                         Life of Pi
# 0446672211          585  Where the Heart Is (Oprah's Book Club (Paperba...
# 0385504209          883                                  The Da Vinci Code
# 0440211727          517                                     A Time to Kill
# 0060928336          732    Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 0671003755          446  She's Come Undone (Oprah's Book Club (Paperback))
# 0345370775          466                                      Jurassic Park
# 0060930535          494                      The Poisonwood Bible: A Novel
# 0743418174          470                                        Good in Bed
# 0440226430          482                                     Summer Sisters
# 067976402X          614                             Snow Falling on Cedars
# 059035342X          571  Harry Potter and the Sorcerer's Stone (Harry P...
# 0440214041          523                                  The Pelican Brief
# 0345337662          506                         Interview with the Vampire
# 0446605239          465                                       The Notebook
# 0375727345          552                              House of Sand and Fog
# 0316601950          568                         The Pilot's Wife : A Novel
# 0440241073          456                                        The Summons

# %%
print('-----------------------------------------------------------------------------')
print('Usuários de quais localizações ou faixas etárias tendem a avaliar mais livros?')
print('-----------------------------------------------------------------------------')

avaliacoes_por_localizacao = df_ratings_v1.groupby('User-ID').agg({'ISBN': 'count'})
avaliacoes_por_localizacao = avaliacoes_por_localizacao.rename(columns={'ISBN': 'Avaliacoes'})

avaliacoes_localizacao = pd.merge(avaliacoes_por_localizacao, df_users_v1[['User-ID', 'Location']], on='User-ID', how='left')

avaliacoes_por_localizacao = avaliacoes_localizacao.groupby('Location')['Avaliacoes'].sum().sort_values(ascending=False)

print("Localizações que mais avaliam livros:")
print(avaliacoes_por_localizacao.head(15))
# Out:
# -----------------------------------------------------------------------------
# Usuários de quais localizações ou faixas etárias tendem a avaliar mais livros?
# -----------------------------------------------------------------------------
# Localizações que mais avaliam livros:
# Location
# toronto, ontario, canada           16431
# n/a, n/a, n/a                      13623
# ottawa, ontario, canada             9075
# chicago, illinois, usa              8722
# seattle, washington, usa            8541
# olympia, washington, usa            8033
# london, england, united kingdom     7979
# omaha, nebraska, usa                7856
# little canada, minnesota, usa       7552
# st. louis, missouri, usa            7366
# duluth, minnesota, usa              6453
# san diego, california, usa          6279
# portland, oregon, usa               6243
# ft. stewart, georgia, usa           6116
# calgary, alberta, canada            6013
# Name: Avaliacoes, dtype: int64

# %%
faixas_etarias = pd.cut(df_users_v1['Age'], bins=[0, 18, 30, 40, 50, 60, 70, 80, 90, 100], labels=['0-18', '19-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90', '91-100'])

df_users_v1['Faixa Etária'] = faixas_etarias
avaliacoes_por_faixa_etaria = pd.merge(df_ratings_v1, df_users_v1[['User-ID', 'Faixa Etária']], on='User-ID', how='left')

avaliacoes_por_faixa_etaria = avaliacoes_por_faixa_etaria.groupby('Faixa Etária')['ISBN'].count().sort_values(ascending=False)

print("Faixas etárias que mais avaliam livros:")
print(avaliacoes_por_faixa_etaria)
# Out:
# Faixas etárias que mais avaliam livros:
# Faixa Etária
# 31-40     260297
# 19-30     251664
# 41-50     159448
# 51-60      95402
# 0-18       34601
# 61-70      30003
# 71-80       3104
# 91-100       742
# 81-90        656
# Name: ISBN, dtype: int64
# /var/folders/jv/x960ph5j46g4834_92nzcq900000gp/T/ipykernel_30564/73108388.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avaliacoes_por_faixa_etaria = avaliacoes_por_faixa_etaria.groupby('Faixa Etária')['ISBN'].count().sort_values(ascending=False)
